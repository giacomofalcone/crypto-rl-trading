# %% [markdown]
# # 0. Install and Import dependencies

# %%
# !pip install tensorflow stable-baselines3[extra] gymnasium gym-trading-env finta
# Out:
# Requirement already satisfied: tensorflow in c:\users\giaco\anaconda3\lib\site-packages (2.16.1)
# Requirement already satisfied: gymnasium in c:\users\giaco\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: gym-trading-env in c:\users\giaco\anaconda3\lib\site-packages (0.3.5)
# Requirement already satisfied: finta in c:\users\giaco\anaconda3\lib\site-packages (1.3)
# Requirement already satisfied: stable-baselines3[extra] in c:\users\giaco\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.10.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\giaco\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.23.5)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\giaco\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.7.0)
# Requirement already satisfied: cloudpickle in c:\users\giaco\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in c:\users\giaco\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.1.4)
# Requirement already satisfied: matplotlib in c:\users\giaco\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.10.1)
# Requirement already satisfied: opencv-python in c:\users\giaco\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.11.0.86)
# Requirement already satisfied: pygame in c:\users\giaco\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: psutil in c:\users\giaco\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: tqdm in c:\users\giaco\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.65.0)
# Requirement already satisfied: rich in c:\users\giaco\anaconda3\lib\site-packages (from stable-baselines3[extra]) (13.3.5)
# Requirement already satisfied: ale-py>=0.9.0 in c:\users\giaco\anaconda3\lib\site-packages (from stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: pillow in c:\users\giaco\anaconda3\lib\site-packages (from stable-baselines3[extra]) (10.2.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\giaco\anaconda3\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: flask==2.2.5 in c:\users\giaco\anaconda3\lib\site-packages (from gym-trading-env) (2.2.5)
# Requirement already satisfied: pyecharts>=2.0.2 in c:\users\giaco\anaconda3\lib\site-packages (from gym-trading-env) (2.0.8)
# Requirement already satisfied: ccxt==3.0.59 in c:\users\giaco\anaconda3\lib\site-packages (from gym-trading-env) (3.0.59)
# Requirement already satisfied: nest_asyncio in c:\users\giaco\anaconda3\lib\site-packages (from gym-trading-env) (1.6.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\giaco\anaconda3\lib\site-packages (from ccxt==3.0.59->gym-trading-env) (2024.2.2)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\giaco\anaconda3\lib\site-packages (from ccxt==3.0.59->gym-trading-env) (42.0.2)
# Requirement already satisfied: aiohttp>=3.8 in c:\users\giaco\anaconda3\lib\site-packages (from ccxt==3.0.59->gym-trading-env) (3.9.3)
# Requirement already satisfied: aiodns>=1.1.1 in c:\users\giaco\anaconda3\lib\site-packages (from ccxt==3.0.59->gym-trading-env) (3.4.0)
# Requirement already satisfied: yarl>=1.7.2 in c:\users\giaco\anaconda3\lib\site-packages (from ccxt==3.0.59->gym-trading-env) (1.9.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\giaco\anaconda3\lib\site-packages (from flask==2.2.5->gym-trading-env) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\giaco\anaconda3\lib\site-packages (from flask==2.2.5->gym-trading-env) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\giaco\anaconda3\lib\site-packages (from flask==2.2.5->gym-trading-env) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\giaco\anaconda3\lib\site-packages (from flask==2.2.5->gym-trading-env) (8.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\giaco\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\giaco\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\giaco\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: prettytable in c:\users\giaco\anaconda3\lib\site-packages (from pyecharts>=2.0.2->gym-trading-env) (3.16.0)
# Requirement already satisfied: simplejson in c:\users\giaco\anaconda3\lib\site-packages (from pyecharts>=2.0.2->gym-trading-env) (3.20.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\giaco\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\giaco\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: filelock in c:\users\giaco\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.13.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\giaco\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.14.0)
# Requirement already satisfied: networkx in c:\users\giaco\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: fsspec in c:\users\giaco\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2023.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\giaco\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\giaco\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\giaco\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\giaco\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\giaco\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\giaco\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\giaco\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: colorama in c:\users\giaco\anaconda3\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: pycares>=4.0.0 in c:\users\giaco\anaconda3\lib\site-packages (from aiodns>=1.1.1->ccxt==3.0.59->gym-trading-env) (4.8.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\giaco\anaconda3\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\giaco\anaconda3\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\giaco\anaconda3\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\giaco\anaconda3\lib\site-packages (from aiohttp>=3.8->ccxt==3.0.59->gym-trading-env) (6.0.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\giaco\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.41.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\giaco\anaconda3\lib\site-packages (from cryptography>=2.6.1->ccxt==3.0.59->gym-trading-env) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\giaco\anaconda3\lib\site-packages (from Jinja2>=3.0->flask==2.2.5->gym-trading-env) (2.1.3)
# Requirement already satisfied: namex in c:\users\giaco\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\giaco\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.13.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\giaco\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->stable-baselines3[extra]) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\giaco\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\giaco\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\giaco\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.7)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\giaco\anaconda3\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: wcwidth in c:\users\giaco\anaconda3\lib\site-packages (from prettytable->pyecharts>=2.0.2->gym-trading-env) (0.2.5)
# Requirement already satisfied: pycparser in c:\users\giaco\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt==3.0.59->gym-trading-env) (2.21)

# %%
import gymnasium as gym
from gymnasium import spaces

# Stable Baselines3
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import PPO

# Processing libraries
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from finta import TA

# %% [markdown]
# # 1. Load BTCUSD Data
# https://www.coingecko.com/it/monete/bitcoin/historical_data?start=2025-01-01&end=2025-05-26
# https://www.marketwatch.com/investing/cryptocurrency/btcusd/download-data?mod=mw_quote_ta

# %%
# Load DataFrame
df = pd.read_csv('data/BTCUSD.csv')

# Convert the 'date' column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Apply numeric conversion to the columns
colonne_prezzo_lower = ['Open', 'High', 'Low', 'Close'] # Volume will be handled if it's already numeric

for colonna in colonne_prezzo_lower:
    if colonna in df.columns:
        print(f"Processing column: {colonna}...")
        if df[colonna].dtype == 'object': # Apply only if it's a string
            df[colonna] = df[colonna].astype(str).str.replace(',', '', regex=False)
        df[colonna] = pd.to_numeric(df[colonna], errors='coerce')
    else:
        print(f"Attention: column '{colonna}' is not present in the DataFrame.")

print("First rows of the DataFrame after renaming and conversion:")
print(df.head())
# Out:
# Processing column: Open...
# Processing column: High...
# Processing column: Low...
# Processing column: Close...
# First rows of the DataFrame after renaming and conversion:
#         Date   Open   High    Low  Close        Volume
# 0 2022-06-01  31624  31948  29881  30104  2.977057e+10
# 1 2022-06-02  30102  30362  29329  30275  3.555333e+10
# 2 2022-06-03  30275  30659  29255  29552  2.423240e+10
# 3 2022-06-04  29552  29941  29466  29634  2.199786e+10
# 4 2022-06-05  29634  30138  29528  30035  1.291138e+10

# %%
# Rename columns to lowercase
df.rename(columns={
    'Date': 'date',     # gym-trading-env doesn't use 'date' as an index by default, but handles it
    'Open': 'open',
    'High': 'high',
    'Low': 'low',
    'Close': 'close',
    'Volume': 'volume'
}, inplace=True)

# %% [markdown]
# # 2. Build Environment

# %% [markdown]
# ## 2.1 Add Custom Indicators (SMA, RSI and OBV)

# %%
# Calculate indicators
df['sma'] = TA.SMA(df, period=12)  # Short-term SMA
df['rsi'] = TA.RSI(df, period=14) # / 100.0  # Normalize RSI to [0, 1]

# Long-Term Indicators:
df['sma_200'] = TA.SMA(df, period=200)
df['distance_from_sma_200'] = (df['close'] - df['sma_200']) / df['sma_200']

df['daily_return'] = df['close'].pct_change()
df['volatility_100'] = df['daily_return'].rolling(window=100).std()

df['min_200'] = df['close'].rolling(window=200).min()
df['max_200'] = df['close'].rolling(window=200).max()
df['position_in_200_range'] = (df['close'] - df['min_200']) / (df['max_200'] - df['min_200'])

# Drop intermediate columns not needed in final dataset
df.drop(columns=['daily_return', 'min_200', 'max_200'], inplace=True)

# Fill any remaining NaNs
df.fillna(0, inplace=True)

# Slice to remove warm-up period rows (safely remove first 200 rows for longest rolling calc)
df_processed = df.iloc[200:].copy()

# Optional: reset index if needed
df_processed.reset_index(drop=True, inplace=True)

# Display result
print(df_processed.head(15))
# Out:
#          date   open   high    low  close        volume           sma  \
# 0  2022-12-18  16706  16798  16669  16760  1.508638e+10  17151.083333
# 1  2022-12-19  16760  16832  16531  16595  1.113405e+10  17131.833333
# 2  2022-12-20  16595  17046  16288  16862  1.771967e+10  17103.833333
# 3  2022-12-21  16861  16924  16738  16780  2.493822e+10  17077.083333
# 4  2022-12-22  16780  16863  16566  16781  1.606277e+10  17044.416667
# 5  2022-12-23  16780  16917  16764  16804  1.784783e+10  17019.333333
# 6  2022-12-24  16804  16854  16763  16842  1.676539e+10  16996.083333
# 7  2022-12-25  16842  16851  16734  16768  1.016985e+10  16914.083333
# 8  2022-12-26  16768  16912  16766  16839  1.257445e+10  16836.083333
# 9  2022-12-27  16839  16962  16601  16655  1.257500e+10  16772.416667
# 10 2022-12-28  16655  16772  16560  16589  1.743606e+10  16748.416667
# 11 2022-12-29  16588  16650  16468  16596  1.911361e+10  16739.250000
# 12 2022-12-30  16595  16643  16353  16561  1.568373e+10  16722.666667
# 13 2022-12-31  16561  16629  16529  16556  1.749733e+10  16719.416667
# 14 2023-01-01  16556  16617  16469  16599  1.201325e+10  16697.500000
#
#           rsi    sma_200  distance_from_sma_200  volatility_100  \
# 0   43.941320  20502.190              -0.182526        0.029084
# 1   41.757976  20433.790              -0.187865        0.029052
# 2   46.399199  20370.340              -0.172228        0.029107
# 3   45.207694  20306.070              -0.173646        0.028840
# 4   45.226167  20239.800              -0.170891        0.027252
# 5   45.679778  20166.585              -0.166740        0.027218
# 6   46.468565  20095.695              -0.161910        0.027210
# 7   45.095276  20028.955              -0.162812        0.027202
# 8   46.722175  19963.240              -0.156500        0.027125
# 9   43.153469  19901.700              -0.163137        0.027111
# 10  41.916708  19841.785              -0.163936        0.027096
# 11  42.106222  19787.750              -0.161299        0.026973
# 12  41.379235  19754.780              -0.161671        0.026972
# 13  41.269613  19726.685              -0.160731        0.026921
# 14  42.676094  19701.720              -0.157485        0.026812
#
#     position_in_200_range
# 0                0.063269
# 1                0.052746
# 2                0.069775
# 3                0.064545
# 4                0.064609
# 5                0.067926
# 6                0.074854
# 7                0.070353
# 8                0.081167
# 9                0.069275
# 10               0.070563
# 11               0.095811
# 12               0.091761
# 13               0.091183
# 14               0.096158

# %%
# This function creates a normalized observation vector for the agent at a given timestep
def get_normalized_observation(df_processed, # your full DataFrame (with engineered features)
                               current_idx, # the current timestep index
                               window_size, # how many past days to include in the observation
                               volume_scaler, # scaler fit on log(volume)
                               long_term_feature_scalers): # dictionary of scalers for long-term features
    start_idx = current_idx - window_size + 1 # compute the starting index of the sliding window
    if start_idx < 0:
        raise IndexError("Not enough data for the observation window.")
        
    window_df = df_processed.iloc[start_idx : current_idx + 1] # slice of the df that represents the window of past data

    price_cols = ['open', 'high', 'low', 'close', 'sma'] # price-related features to be normalized
    first_close = window_df['close'].iloc[0]
    
    # Normalize price-like features relative to the first close in the window
    if abs(first_close) < 1e-9: # if it's to close to 0
        price_features = [np.zeros(window_size, dtype=np.float32) for _ in price_cols]
    else: # normalize all prices by dividing by the first close and subtracting 1: makes first value 0 and rest relative
        price_features = [(window_df[col].values / first_close) - 1.0 for col in price_cols]

    # Traded volume of Bitcoin typically has large values and it tends to be very skewed
    # Normalize volume: apply log transform to reduce skew, then scale to [0, 1] for model input
    if 'volume_log' not in window_df.columns:
        window_df = window_df.copy() # changing df from a view to an isolated copy (no link to the original df)
        window_df['volume_log'] = np.log1p(window_df['volume']) # np.log1p(volume) == log(1 + volume)
    normalized_volume = volume_scaler.transform(window_df[['volume_log']]).flatten() # minmax scaling wrt training data

    # Normalize RSI (0–1 scale)
    normalized_rsi = window_df['rsi'].values / 100.0 # RSI is already bounded between 0–100, so dividing by 100 puts it on a 0–1 scale

    # Normalize long-term features from the current day using pre-fit scalers (mean=0, std=1)
    current_features = df_processed.iloc[current_idx]
    normalized_long_term = [
        scaler.transform(pd.DataFrame({name: [current_features[name]]}))[0, 0]
        for name, scaler in long_term_feature_scalers.items()
    ] # The result is a list of normalized long-term feature values, e.g.: normalized_long_term = [0.42, -0.18, 1.25]

    # Combine all into one observation vector
    observation = np.concatenate([
        np.concatenate(price_features),
        normalized_volume,
        normalized_rsi,
        np.array(normalized_long_term)
    ])
    return observation.astype(np.float32)

# Plots and prints values from a single observation vector
def inspect_single_observation(obs_vector, window_size,
                               window_names, # list of labels for windowed features
                               long_term_names, desc="Sample",
                               n=3): # how many values to show from start/end
    total_window_elements = len(window_names) * window_size
    window_part = obs_vector[:total_window_elements] # windowed time-series features
    long_term_part = obs_vector[total_window_elements:] # static daily features

    print(f"\n--- {desc} ---")
    # Loop over each windowed feature, extract its values, print the first/last few (n) values, and plot them
    for i, name in enumerate(window_names):
        vals = window_part[i * window_size : (i + 1) * window_size]
        print(f"{name}: {vals[:n]} ... {vals[-n:]}")
        plt.plot(vals, label=name, marker='.', linestyle='-')

    if long_term_names: # if there are long-term features, print each one’s value
        print("\nLong-Term Features:")
        for name, val in zip(long_term_names, long_term_part):
            print(f"  {name}: {val:.4f}")

    plt.title(f"{desc} - Normalized Features")
    plt.xlabel("Days in Window")
    plt.ylabel("Normalized Value")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# --- Add volume_log column ---
df_processed['volume_log'] = np.log1p(df_processed['volume'])

# --- Fit scalers on training data only ---
train_split_idx = int(len(df_processed) * 0.8)
train_df = df_processed.iloc[:train_split_idx].copy()

# volume_scaler learns min and max values from the training data only and then uses that to scale future data consistently
volume_scaler = MinMaxScaler().fit(train_df[['volume_log']])

lt_features = ['distance_from_sma_200', 'volatility_100', 'position_in_200_range']
long_term_feature_scalers = {
    feat: StandardScaler().fit(train_df[[feat]]) for feat in lt_features
}

# --- Feature/Plot Labels ---
WINDOW_SIZE = 30
window_names = [
    'open (norm)', 'high (norm)', 'low (norm)', 'close (norm)', 'sma (norm)',
    'volume (log+scaled)', 'rsi (/100)'
]
long_term_names = [f'{f} (scaled)' for f in lt_features]

# --- Inspect a few sample observations ---
# Inspects 3 sample observations from the dataset at increasing intervals (every 50 days),
# to visually verify that features are scaled and encoded correctly
for i in range(min(3, len(df_processed) - WINDOW_SIZE + 1)):
    current_idx = WINDOW_SIZE - 1 + i * 50
    obs = get_normalized_observation(
        df_processed, current_idx, WINDOW_SIZE, volume_scaler, long_term_feature_scalers
    )
    inspect_single_observation(obs, WINDOW_SIZE, window_names, long_term_names, desc=f"Index {current_idx}")
# Out:
# --- Index 29 ---
# open (norm): [-0.00322196  0.         -0.00984487] ... [0.16193317 0.24576372 0.24749403]
# high (norm): [0.0022673  0.00429594 0.01706444] ... [0.26712412 0.25692123 0.2786396 ]
# low (norm): [-0.00542959 -0.01366348 -0.02816229] ... [0.15692124 0.2276253  0.23108593]
# close (norm): [ 0.         -0.00984487  0.00608592] ... [0.24576372 0.24749403 0.2699284 ]
# sma (norm): [0.02333433 0.02218576 0.02051512] ... [0.05792065 0.07905231 0.10133751]
# volume (log+scaled): [0.6281254  0.5753871  0.65605545] ... [0.79528457 0.8343944  0.70187837]
# rsi (/100): [0.4394132  0.41757977 0.463992  ] ... [0.90512174 0.9057841  0.9141514 ]
#
# Long-Term Features:
#   distance_from_sma_200 (scaled): -0.4912
#   volatility_100 (scaled): 0.7263
#   position_in_200_range (scaled): -0.4851
# --- Index 79 ---
# open (norm): [-0.00517211  0.          0.00873609] ... [-0.03298853 -0.02590403 -0.02855529]
# high (norm): [0.00604138 0.01447323 0.01855876] ... [-0.01586405 -0.01808067 -0.01994958]
# low (norm): [-0.01577712 -0.01573366 -0.01425591] ... [-0.03637865 -0.03142385 -0.04624479]
# close (norm): [ 0.          0.00873609 -0.00730181] ... [-0.02590403 -0.02855529 -0.04133345]
# sma (norm): [0.00970677 0.01003999 0.00905482] ... [ 0.00678749  0.00157192 -0.00524455]
# volume (log+scaled): [0.7270926  0.76900524 0.7923433 ] ... [0.60744864 0.6391996  0.6865713 ]
# rsi (/100): [0.60667515 0.6221558  0.5772391 ] ... [0.4338226  0.42845315 0.40258995]
#
# Long-Term Features:
#   distance_from_sma_200 (scaled): -0.3470
#   volatility_100 (scaled): -0.9918
#   position_in_200_range (scaled): -0.2377
# --- Index 129 ---
# open (norm): [-1.6769961e-02  7.2912866e-05  3.5909589e-02] ... [ 0.00174991 -0.00178637  0.00699964]
# high (norm): [0.00262486 0.04385709 0.06354357] ... [0.02048852 0.01206708 0.09398469]
# low (norm): [-0.02774335 -0.01086402  0.01093693] ... [-0.01567627 -0.00816624  0.00699964]
# close (norm): [0.         0.03561794 0.02016041] ... [-0.00182282  0.00703609  0.01753554]
# sma (norm): [0.00622494 0.01084579 0.01254101] ... [0.05793231 0.04960809 0.04220744]
# volume (log+scaled): [0.66371566 0.6554551  0.6863466 ] ... [0.58002704 0.6430751  0.6494876 ]
# rsi (/100): [0.5896048  0.62647027 0.6012289 ] ... [0.4308591  0.45152834 0.4758253 ]
#
# Long-Term Features:
#   distance_from_sma_200 (scaled): 0.5332
#   volatility_100 (scaled): 1.1762
#   position_in_200_range (scaled): 0.3657

# %% [markdown]
# ## 2.2 Create New Environments

# %%
class BitcoinTradingEnv(gym.Env): # OpenAI Gym enviroment
    metadata = {'render_modes': ['human'], 'render_fps': 30}

    # Constructor
    def __init__(self,
                 df, # dataframe with historical data (price, volume, etc.)
                 window_size, # how many days of historical data to use in the observation
                 initial_balance, # starting USD amount
                 volume_scaler, long_term_feature_scalers, # normalization tools
                 transaction_cost_pct=0.0):  # transaction fee (not used here)
        
        super().__init__() # initializes the parent gym.Env class

        # Store inputs as instance variables
        self.df = df
        self.window_size = window_size
        self.initial_balance = initial_balance
        self.volume_scaler = volume_scaler
        self.long_term_feature_scalers = long_term_feature_scalers
        self.transaction_cost_pct = transaction_cost_pct

        # Parameters for the environment logic
        self.holding_penalty_pct = 0.0001 # penalty for holding during volatility
        self.action_reward = 1.0  # bonus for any trade

        # Define action and observation spaces
        self.action_space = spaces.Discrete(3) # buy, hold, sell
        self.obs_vector_length = (5 * window_size) + window_size + window_size + len(long_term_feature_scalers)
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.obs_vector_length,), dtype=np.float32
        ) # an array (1D vector of floats with no bounds) containing the 30 days window with all 7 features + the 2 long term features

        # Initialize the environment state
        self.reset()

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = self.window_size - 1 # start after window_size to ensure a full historical window is available
        self.balance = self.initial_balance # starting with initial_balance USD
        self.btc_held = 0.0 # starting with 0 BTC
        self.net_worth = self.initial_balance
        self.max_steps = len(self.df) - 1 # agent goes through all the dataset (training or testing)
        self.prev_price = self._get_current_price()
        self.buy_price = None
        return self._get_observation(), self._get_info()

    def _get_current_price(self): # returns the current closing price
        return self.df['close'].iloc[self.current_step]

    # Builds the state from historical and long-term features
    def _get_observation(self):
        return get_normalized_observation( # call the function to get and normalize the previous 30 days
            self.df, self.current_step, self.window_size,
            self.volume_scaler, self.long_term_feature_scalers
        )

    # Returns details about the environment’s current state for logging/debugging
    def _get_info(self):
        return {
            "step": self.current_step,
            "balance": self.balance,
            "btc_held": self.btc_held,
            "net_worth": self.net_worth,
            "current_price": self._get_current_price()
        }

    # Executes one step in the environment based on the action taken
    def step(self, action):
        prev_net_worth = self.net_worth
        current_price = self._get_current_price()
        reward = 0.0

        # --- ACTION EXECUTION ---
        # Buy: opens a position if you're holding cash
        # Sell: closes that position if you're holding BTC
        # There is no concept of shorting here:
        # selling only happens if BTC is held, and buying only happens if you have cash
        
        # Buy
        if action == 1 and self.balance > 0:  # Buys all the balance into BTC at the current price
            amount = self.balance
            btc_bought = amount / current_price if current_price > 0 else 0
            self.btc_held += btc_bought
            self.balance = 0
            self.buy_price = current_price # stores buy_price for profit calculation on sell
            reward += self.action_reward # adds a small reward for making a trade

        # Sell
        elif action == 2 and self.btc_held > 0:  # Sells all the BTC at the current price
            sell_value = self.btc_held * current_price
            self.balance += sell_value
            self.btc_held = 0

            if self.buy_price: # if buy_price is set, calculates profit % and add reward
                profit_pct = (current_price - self.buy_price) / self.buy_price
                reward += profit_pct * 100  # amplify profit reward
            reward += self.action_reward # adding the small reward for taking an action (a trade)
            self.buy_price = None # because the trade (long) is concluded

        # Update net worth
        self.net_worth = self.balance + self.btc_held * current_price
        # Give a reward for an every step feedback and to encourage the agent to exit losing positions
        reward += (self.net_worth - prev_net_worth) * 0.01  # small net worth delta

        # Penalty for holding in volatile conditions (missing opportunities or not avoiding losses)
        price_change = abs(current_price - self.prev_price) / self.prev_price if self.prev_price > 0 else 0 # relative price change
        high_volatility = price_change > 0.005 # volatile market if the price changed 0,5% w.r.t. the previous day
        
        # Hold
        if action == 0 and self.btc_held > 0 and high_volatility: # Holds: does nothing
            reward -= self.holding_penalty_pct * self.initial_balance # applies a small penalty for holding BTC during volatile price changes
            # should exit risky positions or capitalize on profitable ones

        self.prev_price = current_price
        self.current_step += 1 # move to the next time step

        # Ends episode if: reached end of dataset or the net worth falls below 10% of initial balance
        terminated = self.current_step >= self.max_steps or self.net_worth <= self.initial_balance * 0.1
        truncated = False

        # In Gym environments, the step() function must always return an observation, even if the episode has ended 
        observation = (
            self._get_observation() if not terminated
            else np.zeros(self.observation_space.shape, dtype=np.float32) # if episode is over, return a dummy observation
        )

        return observation, reward, terminated, truncated, self._get_info()

    # Print summary of the current portfolio status
    def render(self):
        print(f"Step: {self.current_step} | Net Worth: ${self.net_worth:.2f} | BTC Held: {self.btc_held:.6f} | Balance: ${self.balance:.2f}")

# %% [markdown]
# # 3. Training

# %%
# Parameters
WINDOW_SIZE = 30
INITIAL_BALANCE = 10000
TRANSACTION_COST = 0 #0.001  # example value

# Split dataset
train_ratio = 0.8
split_idx = int(len(df_processed) * train_ratio)

df_train = df_processed.iloc[:split_idx].reset_index(drop=True)
df_test = df_processed.iloc[split_idx:].reset_index(drop=True)

# Arguments for the environment constructor
train_env_args = dict(
    df=df_train,
    window_size=WINDOW_SIZE,
    initial_balance=INITIAL_BALANCE,
    volume_scaler=volume_scaler,
    long_term_feature_scalers=long_term_feature_scalers,
    transaction_cost_pct=TRANSACTION_COST
)

test_env_args = dict(
    df=df_test,
    window_size=WINDOW_SIZE,
    initial_balance=INITIAL_BALANCE,
    volume_scaler=volume_scaler,
    long_term_feature_scalers=long_term_feature_scalers,
    transaction_cost_pct=TRANSACTION_COST
)

def make_train_env():
    return BitcoinTradingEnv(**train_env_args)

def make_test_env():
    return BitcoinTradingEnv(**test_env_args)

# Vectorized Envs
train_vec_env = DummyVecEnv([make_train_env])
test_vec_env = DummyVecEnv([make_test_env])

# %%
learning_rate_value = 0.0005

model = PPO("MlpPolicy", train_vec_env, verbose=1, tensorboard_log="./ppo_bitcoin_tensorboard2/", learning_rate=learning_rate_value)
model.learn(total_timesteps=300000)
model.save("ppo_bitcoin_trader_300k_moreTrades")
# Out:
# Using cpu device
# Logging to ./ppo_bitcoin_tensorboard2/PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 291  |
# |    iterations      | 1    |
# |    time_elapsed    | 7    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 275         |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010529792 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00205    |
# |    learning_rate        | 0.0005      |
# |    loss                 | 74          |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00952    |
# |    value_loss           | 126         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 271         |
# |    iterations           | 3           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009574402 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0898      |
# |    learning_rate        | 0.0005      |
# |    loss                 | 63.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00593    |
# |    value_loss           | 130         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 269          |
# |    iterations           | 4            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0091110645 |
# |    clip_fraction        | 0.0907       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 53.9         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00676     |
# |    value_loss           | 150          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 268          |
# |    iterations           | 5            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0099058105 |
# |    clip_fraction        | 0.0967       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.244        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 35.3         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00661     |
# |    value_loss           | 105          |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 265        |
# |    iterations           | 6          |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01571012 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.964     |
# |    explained_variance   | 0.141      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 52         |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0121    |
# |    value_loss           | 106        |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 264          |
# |    iterations           | 7            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0065563833 |
# |    clip_fraction        | 0.0866       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.941       |
# |    explained_variance   | 0.0937       |
# |    learning_rate        | 0.0005       |
# |    loss                 | 40.1         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00609     |
# |    value_loss           | 158          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 255         |
# |    iterations           | 8           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005946602 |
# |    clip_fraction        | 0.0243      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 81.6        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00205    |
# |    value_loss           | 187         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 249          |
# |    iterations           | 9            |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0073938966 |
# |    clip_fraction        | 0.0526       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.904       |
# |    explained_variance   | 0.349        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 49.7         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 130          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 242          |
# |    iterations           | 10           |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0039438494 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.864       |
# |    explained_variance   | 0.367        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 101          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 164          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 236          |
# |    iterations           | 11           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0067821145 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.825       |
# |    explained_variance   | 0.474        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 59.2         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 124          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 232          |
# |    iterations           | 12           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0024957438 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.814       |
# |    explained_variance   | 0.47         |
# |    learning_rate        | 0.0005       |
# |    loss                 | 63.6         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 218          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 13           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0059041744 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.82        |
# |    explained_variance   | 0.444        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 117          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 232          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 229          |
# |    iterations           | 14           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0063731037 |
# |    clip_fraction        | 0.0733       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.821       |
# |    explained_variance   | 0.564        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 67.7         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00556     |
# |    value_loss           | 202          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 231          |
# |    iterations           | 15           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0044481745 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.811       |
# |    explained_variance   | 0.609        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 71.5         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 147          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 232          |
# |    iterations           | 16           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0050361753 |
# |    clip_fraction        | 0.0476       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.811       |
# |    explained_variance   | 0.585        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 99.3         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 210          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 234          |
# |    iterations           | 17           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0074445857 |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.797       |
# |    explained_variance   | 0.616        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 107          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00294     |
# |    value_loss           | 210          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 235          |
# |    iterations           | 18           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0045444854 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.808       |
# |    explained_variance   | 0.703        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 102          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 168          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 237          |
# |    iterations           | 19           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0023498605 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.784       |
# |    explained_variance   | 0.68         |
# |    learning_rate        | 0.0005       |
# |    loss                 | 95.1         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 187          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 238          |
# |    iterations           | 20           |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0027390062 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.765       |
# |    explained_variance   | 0.708        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 75.8         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 168          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 239         |
# |    iterations           | 21          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006259969 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.779      |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 49.3        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 109         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 240          |
# |    iterations           | 22           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0049436484 |
# |    clip_fraction        | 0.0728       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.767       |
# |    explained_variance   | 0.73         |
# |    learning_rate        | 0.0005       |
# |    loss                 | 42.7         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00358     |
# |    value_loss           | 102          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 23          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004889552 |
# |    clip_fraction        | 0.0669      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.755      |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 44.9        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 80.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 241         |
# |    iterations           | 24          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004689915 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.788      |
# |    explained_variance   | 0.688       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 59.4        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 129         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 241          |
# |    iterations           | 25           |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0043167053 |
# |    clip_fraction        | 0.0658       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.772       |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 44.5         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0045      |
# |    value_loss           | 106          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 26          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009717248 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.747      |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 59.1        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00227    |
# |    value_loss           | 105         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 242          |
# |    iterations           | 27           |
# |    time_elapsed         | 228          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0049086194 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.736       |
# |    explained_variance   | 0.703        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 58.6         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00324     |
# |    value_loss           | 130          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 242         |
# |    iterations           | 28          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.004141843 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.718      |
# |    explained_variance   | 0.721       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 73.1        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00213    |
# |    value_loss           | 123         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 29          |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004372608 |
# |    clip_fraction        | 0.0756      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.726      |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 115         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00627    |
# |    value_loss           | 136         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 243          |
# |    iterations           | 30           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0077430913 |
# |    clip_fraction        | 0.0857       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.721       |
# |    explained_variance   | 0.744        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 49.3         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00442     |
# |    value_loss           | 120          |
# ------------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 244      |
# |    iterations           | 31       |
# |    time_elapsed         | 259      |
# |    total_timesteps      | 63488    |
# | train/                  |          |
# |    approx_kl            | 0.005349 |
# |    clip_fraction        | 0.0418   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.702   |
# |    explained_variance   | 0.678    |
# |    learning_rate        | 0.0005   |
# |    loss                 | 93.6     |
# |    n_updates            | 300      |
# |    policy_gradient_loss | -0.00229 |
# |    value_loss           | 183      |
# --------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 245          |
# |    iterations           | 32           |
# |    time_elapsed         | 267          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0053615524 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.683       |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 56.5         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00452     |
# |    value_loss           | 143          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 33          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.005578066 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 32.4        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00297    |
# |    value_loss           | 100         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 246         |
# |    iterations           | 34          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006189806 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 77.7        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00316    |
# |    value_loss           | 156         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 246          |
# |    iterations           | 35           |
# |    time_elapsed         | 290          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0053914185 |
# |    clip_fraction        | 0.0813       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.664       |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 51           |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00275     |
# |    value_loss           | 103          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 247          |
# |    iterations           | 36           |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0056247213 |
# |    clip_fraction        | 0.0747       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.652       |
# |    explained_variance   | 0.818        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 50           |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0042      |
# |    value_loss           | 101          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 247         |
# |    iterations           | 37          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007974954 |
# |    clip_fraction        | 0.0501      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0005      |
# |    loss                 | 70.2        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00218    |
# |    value_loss           | 127         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 248          |
# |    iterations           | 38           |
# |    time_elapsed         | 313          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0060939454 |
# |    clip_fraction        | 0.0661       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.626       |
# |    explained_variance   | 0.751        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 67.3         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 131          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 39          |
# |    time_elapsed         | 321         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.007600491 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.619      |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 54.4        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00216    |
# |    value_loss           | 168         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 249        |
# |    iterations           | 40         |
# |    time_elapsed         | 328        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.00817907 |
# |    clip_fraction        | 0.0361     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.64      |
# |    explained_variance   | 0.801      |
# |    learning_rate        | 0.0005     |
# |    loss                 | 102        |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00161   |
# |    value_loss           | 167        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 41          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.005716108 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.742       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 67.8        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0015     |
# |    value_loss           | 169         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 42           |
# |    time_elapsed         | 343          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0074354205 |
# |    clip_fraction        | 0.0578       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.645       |
# |    explained_variance   | 0.788        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 76.9         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00352     |
# |    value_loss           | 160          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 43          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007963793 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 42.4        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00206    |
# |    value_loss           | 110         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 44           |
# |    time_elapsed         | 359          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0034052609 |
# |    clip_fraction        | 0.0483       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.636       |
# |    explained_variance   | 0.805        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 89.4         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 131          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 45          |
# |    time_elapsed         | 367         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008115739 |
# |    clip_fraction        | 0.0602      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 140         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00388    |
# |    value_loss           | 203         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 251         |
# |    iterations           | 46          |
# |    time_elapsed         | 375         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008508368 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 37.4        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 94.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 250          |
# |    iterations           | 47           |
# |    time_elapsed         | 383          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0064272126 |
# |    clip_fraction        | 0.0731       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.587       |
# |    explained_variance   | 0.847        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 57.6         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00298     |
# |    value_loss           | 112          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 48           |
# |    time_elapsed         | 391          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0073841517 |
# |    clip_fraction        | 0.0688       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.604       |
# |    explained_variance   | 0.841        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 77.4         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 148          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 49           |
# |    time_elapsed         | 398          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0048900666 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.602       |
# |    explained_variance   | 0.847        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 57.4         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00403     |
# |    value_loss           | 125          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 251          |
# |    iterations           | 50           |
# |    time_elapsed         | 406          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0061634094 |
# |    clip_fraction        | 0.0675       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.591       |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 97.5         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 174          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 51          |
# |    time_elapsed         | 413         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.005493831 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.584      |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 68.7        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00595    |
# |    value_loss           | 183         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 52          |
# |    time_elapsed         | 421         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.006543312 |
# |    clip_fraction        | 0.0681      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 73.1        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 145         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 53           |
# |    time_elapsed         | 428          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0055026123 |
# |    clip_fraction        | 0.0606       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.576       |
# |    explained_variance   | 0.795        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 210          |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00561     |
# |    value_loss           | 325          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 54           |
# |    time_elapsed         | 436          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0065134875 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.556       |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.0005       |
# |    loss                 | 73.1         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.000688    |
# |    value_loss           | 168          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 252         |
# |    iterations           | 55          |
# |    time_elapsed         | 446         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.005248124 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.546      |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 57.5        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.000412   |
# |    value_loss           | 127         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 56           |
# |    time_elapsed         | 454          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0081357155 |
# |    clip_fraction        | 0.0692       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.533       |
# |    explained_variance   | 0.744        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 94.3         |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.00046     |
# |    value_loss           | 248          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 252          |
# |    iterations           | 57           |
# |    time_elapsed         | 462          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0044537503 |
# |    clip_fraction        | 0.0982       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.531       |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 194          |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.000916    |
# |    value_loss           | 244          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 58          |
# |    time_elapsed         | 469         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.006032529 |
# |    clip_fraction        | 0.0633      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.54       |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 109         |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.000741   |
# |    value_loss           | 159         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 59          |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.007411119 |
# |    clip_fraction        | 0.0582      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.501      |
# |    explained_variance   | 0.581       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 540         |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00357    |
# |    value_loss           | 673         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 60           |
# |    time_elapsed         | 485          |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0061187968 |
# |    clip_fraction        | 0.0766       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.482       |
# |    explained_variance   | 0.839        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 145          |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 229          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 253          |
# |    iterations           | 61           |
# |    time_elapsed         | 492          |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0048726504 |
# |    clip_fraction        | 0.0756       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.504       |
# |    explained_variance   | 0.764        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 317          |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.0043      |
# |    value_loss           | 485          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 62          |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.009055239 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.51       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 63          |
# |    n_updates            | 610         |
# |    policy_gradient_loss | 0.000265    |
# |    value_loss           | 137         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 63          |
# |    time_elapsed         | 507         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.003840182 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.513      |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 94.6        |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.000798   |
# |    value_loss           | 217         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 254         |
# |    iterations           | 64          |
# |    time_elapsed         | 515         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# ...
# |    iterations           | 127         |
# |    time_elapsed         | 1009        |
# |    total_timesteps      | 260096      |
# | train/                  |             |
# |    approx_kl            | 0.013476387 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.358      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 94.4        |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | 0.000561    |
# |    value_loss           | 175         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 128          |
# |    time_elapsed         | 1017         |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0036559927 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.353       |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 323          |
# |    n_updates            | 1270         |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 614          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 129         |
# |    time_elapsed         | 1025        |
# |    total_timesteps      | 264192      |
# | train/                  |             |
# |    approx_kl            | 0.008042328 |
# |    clip_fraction        | 0.0558      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.348      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 173         |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | -3.95e-05   |
# |    value_loss           | 345         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 130         |
# |    time_elapsed         | 1034        |
# |    total_timesteps      | 266240      |
# | train/                  |             |
# |    approx_kl            | 0.006875819 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.355      |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 133         |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | 0.0037      |
# |    value_loss           | 193         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 131         |
# |    time_elapsed         | 1042        |
# |    total_timesteps      | 268288      |
# | train/                  |             |
# |    approx_kl            | 0.005516995 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.361      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 288         |
# |    n_updates            | 1300        |
# |    policy_gradient_loss | 0.00212     |
# |    value_loss           | 359         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 132          |
# |    time_elapsed         | 1049         |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0033696098 |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.361       |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 150          |
# |    n_updates            | 1310         |
# |    policy_gradient_loss | 0.000895     |
# |    value_loss           | 619          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 133          |
# |    time_elapsed         | 1057         |
# |    total_timesteps      | 272384       |
# | train/                  |              |
# |    approx_kl            | 0.0030165617 |
# |    clip_fraction        | 0.0569       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.356       |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 238          |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 711          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 134          |
# |    time_elapsed         | 1065         |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0064322166 |
# |    clip_fraction        | 0.0813       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.364       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 170          |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.000353    |
# |    value_loss           | 377          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 135          |
# |    time_elapsed         | 1073         |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0062424913 |
# |    clip_fraction        | 0.092        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.371       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 167          |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | 0.000295     |
# |    value_loss           | 634          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 257         |
# |    iterations           | 136         |
# |    time_elapsed         | 1081        |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.007072599 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 169         |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 420         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 137          |
# |    time_elapsed         | 1089         |
# |    total_timesteps      | 280576       |
# | train/                  |              |
# |    approx_kl            | 0.0036635143 |
# |    clip_fraction        | 0.0723       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.351       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 397          |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | -0.000115    |
# |    value_loss           | 512          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 257          |
# |    iterations           | 138          |
# |    time_elapsed         | 1099         |
# |    total_timesteps      | 282624       |
# | train/                  |              |
# |    approx_kl            | 0.0039516888 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.345       |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 779          |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 1.25e+03     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 139          |
# |    time_elapsed         | 1108         |
# |    total_timesteps      | 284672       |
# | train/                  |              |
# |    approx_kl            | 0.0051842825 |
# |    clip_fraction        | 0.0814       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.341       |
# |    explained_variance   | 0.975        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 295          |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | 0.00147      |
# |    value_loss           | 701          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 140          |
# |    time_elapsed         | 1116         |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0045759827 |
# |    clip_fraction        | 0.076        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.352       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 149          |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | 0.000318     |
# |    value_loss           | 605          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 141         |
# |    time_elapsed         | 1124        |
# |    total_timesteps      | 288768      |
# | train/                  |             |
# |    approx_kl            | 0.005528405 |
# |    clip_fraction        | 0.0766      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.347      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 278         |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | 8.25e-05    |
# |    value_loss           | 419         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 142         |
# |    time_elapsed         | 1134        |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.004941387 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.348      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 152         |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.00127    |
# |    value_loss           | 543         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 143          |
# |    time_elapsed         | 1142         |
# |    total_timesteps      | 292864       |
# | train/                  |              |
# |    approx_kl            | 0.0053563947 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.357       |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0005       |
# |    loss                 | 297          |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 552          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 256          |
# |    iterations           | 144          |
# |    time_elapsed         | 1150         |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0046996353 |
# |    clip_fraction        | 0.0765       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.347       |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 179          |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | 0.00343      |
# |    value_loss           | 451          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 145         |
# |    time_elapsed         | 1159        |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.008410705 |
# |    clip_fraction        | 0.0883      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.338      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 94.3        |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | 0.000118    |
# |    value_loss           | 216         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 146         |
# |    time_elapsed         | 1167        |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 0.004433281 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.327      |
# |    explained_variance   | 0.967       |
# |    learning_rate        | 0.0005      |
# |    loss                 | 329         |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | -0.000554   |
# |    value_loss           | 866         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 255          |
# |    iterations           | 147          |
# |    time_elapsed         | 1176         |
# |    total_timesteps      | 301056       |
# | train/                  |              |
# |    approx_kl            | 0.0043727905 |
# |    clip_fraction        | 0.0608       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.328       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0005       |
# |    loss                 | 827          |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | 0.000143     |
# |    value_loss           | 875          |
# ------------------------------------------

# %% [markdown]
# # 4. Testing

# %%
# Create test environment directly from your class
test_env = BitcoinTradingEnv(**test_env_args)

obs, info = test_env.reset()
done = False

net_worths = [info["net_worth"]]
actions = []
rewards = []

while not done:
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = test_env.step(action)
    done = terminated or truncated
    
    net_worths.append(info["net_worth"])
    rewards.append(reward)
    actions.append(action)

# Plot Net Worth Over Time
plt.figure(figsize=(12, 6))
plt.plot(net_worths, label="Net Worth")
plt.xlabel("Steps")
plt.ylabel("Net Worth ($)")
plt.title("Agent Net Worth Over Test Period")
plt.legend()
plt.grid()
plt.show()

# %%
test_env = BitcoinTradingEnv(**test_env_args)
obs, info = test_env.reset()
done = False

net_worths = [info["net_worth"]]
prices = [info["current_price"]]
actions = []

while not done:
    action, _states = model.predict(obs, deterministic=True)
    action = int(action)  # Convert to int to fix unhashable type error
    obs, reward, terminated, truncated, info = test_env.step(action)
    done = terminated or truncated
    
    net_worths.append(info["net_worth"])
    prices.append(info["current_price"])
    actions.append(action)

actions = [None] + actions  # Align length with prices/net_worths

# Normalize price and net worth to percentage change from first value
price_pct = 100 * (np.array(prices) / prices[0] - 1)
net_worth_pct = 100 * (np.array(net_worths) / net_worths[0] - 1)

fig, ax1 = plt.subplots(figsize=(14, 7))

ax1.plot(price_pct, label='Price % Change', color='blue', alpha=0.7)
ax1.plot(net_worth_pct, label='Net Worth % Change', color='green', alpha=0.7)
ax1.set_xlabel('Steps')
ax1.set_ylabel('Percentage Change (%)')
ax1.legend(loc='upper left')
ax1.grid(True)

ax2 = ax1.twinx()

action_colors = {0: 'gray', 1: 'green', 2: 'red'}
action_labels = {0: 'Hold', 1: 'Buy', 2: 'Sell'}

# To avoid duplicate legend entries
plotted_labels = set()

for i, act in enumerate(actions):
    if act is not None:
        color = action_colors[act]
        label = action_labels[act] if act not in plotted_labels else None
        marker = '^' if act == 1 else ('v' if act == 2 else 'o')
        ax2.scatter(i, 0, color=color, label=label, marker=marker, s=50)
        plotted_labels.add(act)

ax2.set_yticks([])
ax2.set_ylim(-1, 1)
ax2.spines['right'].set_visible(False)

ax2.legend(loc='upper right')

plt.title('Normalized Price & Net Worth with Trading Actions')
plt.show()
